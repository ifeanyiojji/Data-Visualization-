# %% [markdown]
# # 1 Tutorial

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import style

# %%
x_data = np.random.random(1000)*100
y_data = np.random.random(1000)*100

# %%
plt.scatter(x_data, y_data, c = "#000000", marker = "*", s = 150, alpha = 0.3)
plt.show()

# %%
years = [2006 + x for x in range(19)]
print(years)
# Out:
# [2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024]

# %%
weights = [83, 79, 55, 15, 33, 21, 87, 99, 100, 14,25,41,21,21,36,0,14,55,78]
print(weights)
# Out:
# [83, 79, 55, 15, 33, 21, 87, 99, 100, 14, 25, 41, 21, 21, 36, 0, 14, 55, 78]

# %%
plt.plot(years,weights, "y--", lw =1.5)

# %%
x = ["C++", "C#", "Python", "Java", "php"]
y = [50, 21, 180, 69, 13]

# %%
plt.bar(x,y, color ="r", align="edge", width = 0.5, edgecolor = "g", lw =5)
# Out:
# <BarContainer object of 5 artists>

# %%
ages = np.random.normal(20, 7.5, 1000)
plt.hist(ages, bins = 20, cumulative = True)
# Out:
# (array([   3.,    6.,   11.,   22.,   46.,   91.,  154.,  247.,  339.,
#          468.,  612.,  741.,  829.,  902.,  948.,  978.,  995.,  997.,
#          999., 1000.]),
#  array([-5.40390064, -2.87381229, -0.34372395,  2.18636439,  4.71645273,
#          7.24654108,  9.77662942, 12.30671776, 14.83680611, 17.36689445,
#         19.89698279, 22.42707114, 24.95715948, 27.48724782, 30.01733616,
#         32.54742451, 35.07751285, 37.60760119, 40.13768954, 42.66777788,
#         45.19786622]),
#  <BarContainer object of 20 artists>)

# %%
langs = ["C++", "C#", "Python", "Java", "php"]
votes = [50, 21, 180, 69, 13]


plt.pie(votes, labels = langs)
# Out:
# ([<matplotlib.patches.Wedge at 0x1886f0da610>,
# ...
#  [Text(0.9798715003657703, 0.4998518208138631, 'C++'),
#   Text(0.45781451387574484, 1.0002029148551386, 'C#'),
#   Text(-1.09408206489914, 0.1139492661934873, 'Python'),
#   Text(0.6869970945589968, -0.8590896298218814, 'Java'),
#   Text(1.091737384759507, -0.1345714781016843, 'php')])

# %%
langs = ["C++", "C#", "Python", "Java", "php"]
votes = [50, 21, 180, 69, 13]
explode = [0, 0, 0.5,0,0]


plt.pie(votes, labels = langs, explode = explode, autopct ="%.2f%%", pctdistance = 1.55, startangle = 90)
# Out:
# ([<matplotlib.patches.Wedge at 0x188702e8910>,
# ...
#  [Text(-0.4998518208138632, 0.9798715003657703, 'C++'),
#   Text(-1.0002029148551386, 0.4578145138757449, 'C#'),
#   Text(-0.1657443871905271, -1.5913920943987492, 'Python'),
#   Text(0.8590896298218814, 0.6869970945589967, 'Java'),
#   Text(0.13457147810168435, 1.091737384759507, 'php')],
#  [Text(-0.7043366566013527, 1.3807280232426764, '15.02%'),
#   Text(-1.4093768345686044, 0.645102269552186, '6.31%'),
#   Text(-0.2123599960878628, -2.038971120948397, '54.05%'),
#   Text(1.2105353874762874, 0.9680413605149498, '20.72%'),
#   Text(0.18962344641600976, 1.5383572239793055, '3.90%')])

# %%
heights = np.random.normal(172, 8, 300)
plt.boxplot(heights)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x18870485850>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x188704876d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1886f0d7390>],
#  'medians': [<matplotlib.lines.Line2D at 0x18870488b90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x188704898d0>],
#  'means': []}

# %%
first = np.linspace(0,10,25)
second = np.linspace(10,200,25)
third = np.linspace(200,210,25)
fourth = np.linspace(210,230,25)

data = np.concatenate((first, second, third, fourth))


plt.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x188705fa950>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x188706193d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x188705f9350>],
#  'medians': [<matplotlib.lines.Line2D at 0x1887061a750>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1886f0daed0>],
#  'means': []}

# %%
years = [2014 + x for x in range(8)]

income = [55, 56, 62, 61, 72, 72, 73, 75]
income_ticks = list(range(50,81,2))

plt.plot(years,income)
plt.title("Income of John (in USD)", fontsize=30, fontname = "Montserrat")
plt.xlabel("Year")
plt.ylabel("Yearly Income in USD")
plt.yticks(income_ticks, [f"${x}k USD" for x in income_ticks])
# Out:
# ([<matplotlib.axis.YTick at 0x188722e9890>,
# ...
#  [Text(0, 50, '$50k USD'),
#   Text(0, 52, '$52k USD'),
#   Text(0, 54, '$54k USD'),
#   Text(0, 56, '$56k USD'),
#   Text(0, 58, '$58k USD'),
#   Text(0, 60, '$60k USD'),
#   Text(0, 62, '$62k USD'),
#   Text(0, 64, '$64k USD'),
#   Text(0, 66, '$66k USD'),
#   Text(0, 68, '$68k USD'),
#   Text(0, 70, '$70k USD'),
#   Text(0, 72, '$72k USD'),
#   Text(0, 74, '$74k USD'),
#   Text(0, 76, '$76k USD'),
#   Text(0, 78, '$78k USD'),
#   Text(0, 80, '$80k USD')])

# %%
stock_a = [100, 102, 99, 101, 101, 100, 102]
stock_b = [90, 95, 102, 104, 105, 103, 109]
stock_c = [110, 115, 100, 105, 100, 98, 95]

plt.plot(stock_a, label = "Tesla")
plt.plot(stock_b, label = "Netflix")
plt.plot(stock_c, label = "Audi")

plt.legend(loc="lower center")

# %%
votes = [10, 55, 65, 22, 34 ]
people = ["A", "B", "C", "D", "E"]

plt.pie(votes, labels = None)
plt.legend(labels = people)

# %%
x1, y1 = np.random.random(100),np.random.random(100)
x2, y2 = np.arange(100), np.random.random(100)

plt.figure(1)
plt.scatter(x1, y1)

plt.figure(2)
plt.plot(x2, y2)

# %%
x = np.arange(100)

fig, axs = plt.subplots(2,2)

axs[0,0].plot(x,np.sin(x))
axs[0,0].set_title("Sine Wave")

axs[0,1].plot(x,np.cos(x))
axs[0,1].set_title("Cosine Wave")

axs[1,0].plot(x,np.random.random(100))
axs[1,0].set_title("Random Function")

axs[1,1].plot(x,np.log(x))
axs[1,1].set_title("Log Function")


fig.suptitle("Four Plots")

plt.tight_layout()
plt.savefig("Four plots.png", dpi=300, transparent = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_19464\4011314327.py:14: RuntimeWarning: divide by zero encountered in log
#   axs[1,1].plot(x,np.log(x))

# %%
ax = plt.axes(projection = "3d")

x =np.random.random(100)
y =np.random.random(100)
z =np.random.random(100)

ax.scatter(x,y,z)
ax.set_title("3D Plot")
# Out:
# Text(0.5, 0.92, '3D Plot')

# %%
ax = plt.axes(projection="3d")

x = np.arange(-5, 5, 0.1)
y = np.arange(-5, 5, 0.1)

X, Y = np.meshgrid(x, y)

Z = np.sin(X) * np.cos(Y)

ax.plot_surface(X, Y, Z, cmap = "Spectral")
ax.set_title("3D Plot")
ax.set_xlabel("test")
ax.set_ylabel("weight")
ax.set_zlabel("current")
ax.view_init(azim=0, elev=90)

plt.show()

# %%
import random

# %%
heads_tail = [0,0]
for _ in range(1000040):
    heads_tail[random.randint(0,1)] += 1
    plt.bar(["Heads", "Tails"], heads_tail, color=["red", "blue"])
    plt.pause(1)

plt.show()
